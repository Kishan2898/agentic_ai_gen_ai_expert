# %% [markdown]
# # print is use for answer

# %%
a=10 
b=20
a 
b
# Out:
# 20

# %%
a=10 
b=20
print(a) 
print(b)
# Out:
# 10
# 20

# %%
print(10)
print(10,20)
print('python')
print(10,20,'python')
# Out:
# 10
# 10 20
# python
# 10 20 python

# %%
num1=20 
num2=30
add=num1+num2 
print(add)
# Out:
# 50

# %% [markdown]
# #print result with string

# %%
num1=20 
num2=30
add=num1+num2
print('The addition of',num1,'and',num2,'is=',add)
# Out:
# The addition of 20 and 30 is= 50

# %%
name='Python' 
age=20
city='hyd'
#hellow my name is python and i am 10 year old from hydrabad
print('My name is',name,'and i am',age,'years old form',city)
# Out:
# My name is Python and i am 20 years old form hyd

# %%
num1=20
num2=30
add=num1+num2
print('The addition of {} and {} is = {}'.format(num1,num2,add))
# Out:
# The addition of 20 and 30 is = 50

# %% [raw]
# first deside how the print statement should be like:-
# 1. The addition of 20 and 30 is = 50
# 2. then replace the variable position with curly brtacesm { }
# 3. then appply .format(val1,val2,....val-n methodm

# %%
name='Python'
age=20
city='hyd'
#hellow my name is python and i am 10 year old from hydrabad
print('hello my name is {}, and Iam {} years old from {}'.format(name, age, city))
# Out:
# hello my name is Python, and Iam 20 years old from hyd

# %%
num1=100 
num2=25 
num3=333
avg=(num1+num2+num3)/3 # or we can use avg=round(num1+num2+num3)/3,2)
avg1=round((num1+num2+num3)/3,2)
# The avrage of num1,num2,num3 is = avg
print('The avrage of {}, {}, and {} is= {} or {}'.format(num1,num2,num3, avg,avg1)) # here we can use round(avg,2) also
# Out:
# The avrage of 100, 25, and 333 is= 152.66666666666666 or 152.67

# %% [raw]
# More short format meythod(f string method)
# variable should be in curly braces
# and write everything inside quots ''
# at starting simpaly add f

# %%
num1=20 
num2=30
add=num1+num2
print(f'The addition of {num1} and {num2} is= {add}') # always prefer this
# Out:
# The addition of 20 and 30 is= 50

# %% [raw]
# What is f used for in print()?
# The f allows you to directly insert variables and expressions inside a string using {}.
#
# f-strings are faster than .format() and string concatenation.
#
# Interview-ready definition 🧠
#
# f-string is a formatted string literal introduced in Python 3.6 that allows embedding variables and expressions inside string literals using {} for better readability and performance.

# %%
name='Python' 
age=20
city='hyd'
#hellow my name is python and i am 10 year old from hydrabad
print(f'hello my name is {name}, and Iam {age} years old, from {city}.')
# Out:
# hello my name is Python, and Iam 20 years old, from hyd.

# %%
num1=100 
num2=25 
num3=333
avg=round((num1+num2+num3)/3,2) # or we can use avg=round(num1+num2+num3)/3,2) 
# The avrage of num1,num2,num3 is = avg
print(f'The avrage of {num1}, {num2} and {num3} is = {avg}')
# Out:
# The avrage of 100, 25 and 333 is = 152.67

# %%
# lete combine all
num1=10 
num2=20
add = num1+ num2
print('The addition of',num1,'and',num2,'is=',add)
print('The addition of {} and {} is= {}'.format(num1,num2,add)) 
print(f'The addition of {num1} and {num2} is= {add}')
# Out:
# The addition of 10 and 20 is= 30
# The addition of 10 and 20 is= 30
# The addition of 10 and 20 is= 30

# %% [markdown]
# #end statement

# %%
print('hello') # 1st statement
print('good moorning') # 2nd statement)
# i want print like:- hello good morning
# Out:
# hello
# good moorning

# %% [raw]
# Here we will use end statement that joint line from end of one string to starting of other string

# %%
print('hello', end=' ') # 1st statement
print('world good day') # 2nd statement
# Out:
# hello world good day

# %% [markdown]
# Separator

# %% [raw]
# 1. here one print statement only we use
# 2. insisde one print statement we have multipal values
# 3. we want to seperate these multipal values with anything

# %%
print('hello','hai','how are you',sep='--->')
# Out:
# hello--->hai--->how are you

# %%
print(' hello ',' hai ',' how are you ',sep='&')
# Out:
#  hello & hai & how are you

# %%
print('hello','hai','how are you',sep=' ')
# Out:
# hello hai how are you

# %%
print(3,'.') # . is far from 3 so here we will use sep method
# Out:
# 3 .

# %%
print(3,'.',sep='') # see now space setteld(also use to remove space B/W words)

# %%
print(1,2,end=' ') 
print(3,'.',sep='') # will print 1 2 3.
# Out:
# 1 2 3.
